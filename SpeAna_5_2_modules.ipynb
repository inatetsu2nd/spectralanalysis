# %% [markdown]
# ## <span style="color: DeepPink; ">5.5　モジュール化</span>

# %% [markdown]
# #### <span style="color: green; ">from</span> パッケージ名.モジュール名 <span style="color: green; ">import</span>  クラス名

# %%
from SpeAnamodule.spectral_preprocessor import SpectralDataProcessor#①

# %% [markdown]
# #### 利用方法
# ```インスタンス名 = クラス名（引数）```<BR>
# ```インスタンス.関数```

# %%
# 使用例
# processor = SpectralDataProcessor("./dataChapter5/") # ②'
processor = SpectralDataProcessor() # ②
spectra = processor.read_NIR() # ③
derispec = processor.savigolay_deri(window=21, polynom=2, order=2) # ④
snvspe = processor.SNV() # ⑤
